# %%
import pandas as pd

# %%
pd.read_csv("EmployeesInfo.csv",parse_dates=["Start Date"])
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 1       Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 2        Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 3        Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 4        Larry    Male 1998-01-24         4:47 PM  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 995      Henry     NaN 2014-11-23         6:09 AM  132483   16.655
# 996    Phillip    Male 1984-01-31         6:30 AM   42392   19.675
# 997    Russell    Male 2013-05-20        12:39 PM   96914    1.421
# 998      Larry    Male 2013-04-20         4:45 PM   60500   11.985
# 999     Albert    Male 2012-05-15         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df = pd.read_csv("EmployeesInfo.csv")

# %%
df.head(6)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5     Dennis    Male  4/18/1987         1:35 AM  115163   10.125
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services
# 5             False            Legal

# %%
df["Start Date"]= pd.to_datetime( df["Start Date"]) 
# Last Login Time

df["Last Login Time"]= pd.to_datetime( df["Last Login Time"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(4)
# memory usage: 62.6+ KB

# %%
d
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1000 entries, 0 to 999
# Series name: Team
# Non-Null Count  Dtype
# --------------  -----
# 957 non-null    object
# dtypes: object(1)
# memory usage: 7.9+ KB

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2023-02-01 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2023-02-01 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2023-02-01 11:17:00  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
df["First Name"].hasnans
# Out:
# True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2023-02-01 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2023-02-01 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2023-02-01 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2023-02-01 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2023-02-01 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2023-02-01 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2023-02-01 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2023-02-01 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2023-02-01 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2023-02-01 18:24:00  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# ...

# %%
cond1 = df["Gender"]=="Female"

df[cond1] | 

df [ df["Start Date"] < '1987-08-17']
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2023-02-01 01:35:00  115163   10.125
# 10      Louise  Female 1980-08-12 2023-02-01 09:01:00   63241   15.132
# 12     Brandon    Male 1980-12-01 2023-02-01 01:08:00  112807   17.492
# 17       Shawn    Male 1986-12-07 2023-02-01 19:45:00  111737    6.414
# 18       Diana  Female 1981-10-23 2023-02-01 10:27:00  132940   19.082
# ..         ...     ...        ...                 ...     ...      ...
# 983       John    Male 1982-12-23 2023-02-01 22:35:00  146907   11.738
# 985    Stephen     NaN 1983-07-10 2023-02-01 20:10:00   85668    1.909
# 986      Donna  Female 1982-11-26 2023-02-01 07:04:00   82871   17.999
# 990      Robin  Female 1987-07-24 2023-02-01 13:35:00  100765   10.982
# 996    Phillip    Male 1984-01-31 2023-02-01 06:30:00   42392   19.675
#
#     Senior Management             Team
# 5               False            Legal
# ...

# %%
df.sort_values(by="First Name", inplace=True)

# %%
df.head(9)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2023-02-01 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2023-02-01 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2023-02-01 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2023-02-01 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2023-02-01 01:45:00   95327   15.120
# 141       Adam   Male 1990-12-24 2023-02-01 20:57:00  110194   14.727
# 302       Adam   Male 2007-07-05 2023-02-01 11:59:00   71276    5.027
# 538       Adam   Male 2010-10-08 2023-02-01 21:53:00   45181    3.491
# 300       Alan   Male 1988-06-26 2023-02-01 03:54:00  111786    3.592
#
#     Senior Management             Team
# 101              True        Marketing
# 327              True        Marketing
# 440              True  Client Services
# 937             False  Client Services
# 137             False     Distribution
# ...

# %%
df [ ~df["First Name"].duplicated(keep='first')   ]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2023-02-01 10:20:00   61602   11.849
# 137       Adam    Male 2011-05-21 2023-02-01 01:45:00   95327   15.120
# 300       Alan    Male 1988-06-26 2023-02-01 03:54:00  111786    3.592
# 372     Albert    Male 1997-02-01 2023-02-01 16:20:00   67827   19.717
# 988      Alice  Female 2004-10-05 2023-02-01 09:34:00   47638   11.209
# ..         ...     ...        ...                 ...     ...      ...
# 433      Wanda  Female 2008-07-20 2023-02-01 13:44:00   65362    7.132
# 177      Wayne    Male 2012-04-07 2023-02-01 08:00:00  102652   14.085
# 820    William    Male 1993-11-18 2023-02-01 12:27:00   54058    5.182
# 450     Willie    Male 2009-08-22 2023-02-01 13:03:00   55038   19.691
# 7          NaN  Female 2015-07-20 2023-02-01 10:43:00   45906   11.598
#
#     Senior Management             Team
# 101              True        Marketing
# ...

# %%
df.head(4)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2023-02-01 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2023-02-01 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2023-02-01 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2023-02-01 19:39:00   63126   18.424
#
#     Senior Management             Team
# 101              True        Marketing
# 327              True        Marketing
# 440              True  Client Services
# 937             False  Client Services

# %%
~df["First Name"].head(4).duplicated(keep="last")
# Out:
# 101    False
# 327    False
# 440    False
# 937     True
# Name: First Name, dtype: bool

# %%
df["First Name"].head(4).duplicated(keep="last")
# Out:
# 101     True
# 327     True
# 440     True
# 937    False
# Name: First Name, dtype: bool

# %%
df [ ~df["First Name"].duplicated(keep="first")]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2023-02-01 10:20:00   61602   11.849
# 137       Adam    Male 2011-05-21 2023-02-01 01:45:00   95327   15.120
# 300       Alan    Male 1988-06-26 2023-02-01 03:54:00  111786    3.592
# 372     Albert    Male 1997-02-01 2023-02-01 16:20:00   67827   19.717
# 988      Alice  Female 2004-10-05 2023-02-01 09:34:00   47638   11.209
# ..         ...     ...        ...                 ...     ...      ...
# 433      Wanda  Female 2008-07-20 2023-02-01 13:44:00   65362    7.132
# 177      Wayne    Male 2012-04-07 2023-02-01 08:00:00  102652   14.085
# 820    William    Male 1993-11-18 2023-02-01 12:27:00   54058    5.182
# 450     Willie    Male 2009-08-22 2023-02-01 13:03:00   55038   19.691
# 7          NaN  Female 2015-07-20 2023-02-01 10:43:00   45906   11.598
#
#     Senior Management             Team
# 101              True        Marketing
# ...

# %%
df [ df.duplicated(subset="First Name",keep="first") ]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 327      Aaron    Male 1994-01-29 2023-02-01 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2023-02-01 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2023-02-01 19:39:00   63126   18.424
# 141       Adam    Male 1990-12-24 2023-02-01 20:57:00  110194   14.727
# 302       Adam    Male 2007-07-05 2023-02-01 11:59:00   71276    5.027
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2023-02-01 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2023-02-01 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2023-02-01 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2023-02-01 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2023-02-01 05:19:00  143638    9.662
#
#     Senior Management             Team
# 327              True        Marketing
# ...

# %%
df[ ~df.duplicated(subset="First Name",keep=False) ]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2023-02-01 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2023-02-01 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2023-02-01 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2023-02-01 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2023-02-01 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2023-02-01 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2023-02-01 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2023-02-01 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2023-02-01 10:30:00  132839   17.463
#
#     Senior Management                  Team
# 8                True           Engineering
# 688              True                 Legal
# 190             False               Finance
# 887             False                 Legal
# ...

# %%
df.head(6)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2023-02-01 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2023-02-01 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2023-02-01 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2023-02-01 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2023-02-01 01:45:00   95327   15.120
# 141       Adam   Male 1990-12-24 2023-02-01 20:57:00  110194   14.727
#
#     Senior Management             Team
# 101              True        Marketing
# 327              True        Marketing
# 440              True  Client Services
# 937             False  Client Services
# 137             False     Distribution
# 141              True          Product

# %%
df.drop_duplicates(subset="First Name",keep=False)
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2023-02-01 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2023-02-01 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2023-02-01 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2023-02-01 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2023-02-01 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2023-02-01 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2023-02-01 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2023-02-01 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2023-02-01 10:30:00  132839   17.463
#
#     Senior Management                  Team
# 8                True           Engineering
# 688              True                 Legal
# 190             False               Finance
# 887             False                 Legal
# ...

# %%
dummyDF = df.set_index("First Name")

dummyDF
# dummyDF.reset_index(drop=True)
# Out:
#             Gender Start Date     Last Login Time  Salary  Bonus %  \
# First Name
# Aaron         Male 2012-02-17 2023-02-01 10:20:00   61602   11.849
# Aaron         Male 1994-01-29 2023-02-01 18:48:00   58755    5.097
# Aaron         Male 1990-07-22 2023-02-01 14:53:00   52119   11.343
# Aaron          NaN 1986-01-22 2023-02-01 19:39:00   63126   18.424
# Adam          Male 2011-05-21 2023-02-01 01:45:00   95327   15.120
# ...            ...        ...                 ...     ...      ...
# NaN           Male 2001-05-23 2023-02-01 19:52:00  103877    6.322
# NaN         Female 2000-08-23 2023-02-01 16:19:00   95866   19.388
# NaN         Female 1985-09-15 2023-02-01 01:50:00  133472   16.941
# NaN           Male 2012-07-30 2023-02-01 15:07:00  107351    5.329
# NaN         Female 2010-09-14 2023-02-01 05:19:00  143638    9.662
#
#            Senior Management             Team
# First Name
# Aaron                   True        Marketing
# ...

# %%
# #  parse_datea

# %%
# filter

# %%
#  & | and isin

# %%
# isnull & notnull method for null value extraction

# %%
# between - to find data between two ranges

# %%
# .duplicate method to remove the duplicate

# %%
# drop_duplicate() method

# %%
# .unique
# nunique() method

# %%
# set_index

# %%
# reset_index columns

# %%
# loc method ( ending position is included)

# %%
# iloc[row index] ( ending is not included )

# %%
#  setting the value of the dataframe

# %%
# rename method to change the index

# %%
# .drop the drop the index value in row or columns

# %%
# .sample()

# %%
# n largest() or num largest

# %%
# nsmallest()

# %%
#  where

# %%
# query

# %%
# apply => for column & rows

# %%
# series["Column"].str.caseConversion

# %%
# replace

# %%
# str.contains

# %%
# startswith

# %%
# endswith

# %%
# lstrip

# %%
# rstrip & strip

# %%
# split method

# %%
# set_index ( keys=[col1,col2])

# %%
# Get_level_values <= extracting the set of values from here

# %%
# set_names <= to change on the index of the indexes
# df.index.set

# %%
# swaplevel method() : Swap level 👍	: use to swap the level ( interchange the level index)

# %%
# stack

# %%
# unstack

# %%
# pivot method is used to perform reorientation of your dataset
