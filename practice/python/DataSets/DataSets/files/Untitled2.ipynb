# %%
import pandas as pd

# %%
df = pd.read_csv("NbaInfo.csv", index_col=["Name"])

# %%
df =df.dropna()

# %%
df.sort_index(inplace=True)
df
# Out:
#                                        Team  Number Position   Age Height  \
# Name
# Aaron Brooks                  Chicago Bulls     0.0       PG  31.0    6-0
# Aaron Gordon                  Orlando Magic     0.0       PF  20.0    6-9
# Aaron Harrison            Charlotte Hornets     9.0       SG  21.0    6-6
# Adreian Payne        Minnesota Timberwolves    33.0       PF  25.0   6-10
# Al Horford                    Atlanta Hawks    15.0        C  30.0   6-10
# ...                                     ...     ...      ...   ...    ...
# Willie Cauley-Stein        Sacramento Kings     0.0        C  22.0    7-0
# Willie Reed                   Brooklyn Nets    33.0       PF  26.0   6-10
# Wilson Chandler              Denver Nuggets    21.0       SF  29.0    6-8
# Zach LaVine          Minnesota Timberwolves     8.0       PG  21.0    6-5
# Zach Randolph             Memphis Grizzlies    50.0       PF  34.0    6-9
#
#                      Weight         College      Salary  Rank_salary
# ...

# %%
df.columns
# Out:
# Index(['Team', 'Number', 'Position', 'Age', 'Height', 'Weight', 'College',
#        'Salary', 'Rank_salary'],
#       dtype='object')

# %%
#  row label indexing 
df.loc[ "Aaron Brooks":"Al Horford", "Team":"Age" ]
# Out:
#                                   Team  Number Position   Age
# Name
# Aaron Brooks             Chicago Bulls     0.0       PG  31.0
# Aaron Gordon             Orlando Magic     0.0       PF  20.0
# Aaron Harrison       Charlotte Hornets     9.0       SG  21.0
# Adreian Payne   Minnesota Timberwolves    33.0       PF  25.0
# Al Horford               Atlanta Hawks    15.0        C  30.0

# %%
df.drop("Team",axis=1)
# Out:
#                      Number Position   Age Height  Weight         College  \
# Name
# Aaron Brooks            0.0       PG  31.0    6-0   161.0          Oregon
# Aaron Gordon            0.0       PF  20.0    6-9   220.0         Arizona
# Aaron Harrison          9.0       SG  21.0    6-6   210.0        Kentucky
# Adreian Payne          33.0       PF  25.0   6-10   237.0  Michigan State
# Al Horford             15.0        C  30.0   6-10   245.0         Florida
# ...                     ...      ...   ...    ...     ...             ...
# Willie Cauley-Stein     0.0        C  22.0    7-0   240.0        Kentucky
# Willie Reed            33.0       PF  26.0   6-10   220.0     Saint Louis
# Wilson Chandler        21.0       SF  29.0    6-8   225.0          DePaul
# Zach LaVine             8.0       PG  21.0    6-5   189.0            UCLA
# Zach Randolph          50.0       PF  34.0    6-9   260.0  Michigan State
#
#                          Salary  Rank_salary
# Name
# ...

# %%
# df3 = df.pop("Team")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [60], line 2
#       1 # df3 = df.pop("Team")
# ----> 2 type( df3)
#
# NameError: name 'df3' is not defined

# %%
df.drop("Aaron Brooks")
# Out:
#                                        Team  Number Position   Age Height  \
# Name
# Aaron Gordon                  Orlando Magic     0.0       PF  20.0    6-9
# Aaron Harrison            Charlotte Hornets     9.0       SG  21.0    6-6
# Adreian Payne        Minnesota Timberwolves    33.0       PF  25.0   6-10
# Al Horford                    Atlanta Hawks    15.0        C  30.0   6-10
# Al-Farouq Aminu      Portland Trail Blazers     8.0       SF  25.0    6-9
# ...                                     ...     ...      ...   ...    ...
# Willie Cauley-Stein        Sacramento Kings     0.0        C  22.0    7-0
# Willie Reed                   Brooklyn Nets    33.0       PF  26.0   6-10
# Wilson Chandler              Denver Nuggets    21.0       SF  29.0    6-8
# Zach LaVine          Minnesota Timberwolves     8.0       PG  21.0    6-5
# Zach Randolph             Memphis Grizzlies    50.0       PF  34.0    6-9
#
#                      Weight         College      Salary  Rank_salary
# ...

# %%
df.rename(mapper={"Team":"new Team"},axis="columns")
# Out:
#                                    new Team  Number Position   Age Height  \
# Name
# Aaron Brooks                  Chicago Bulls     0.0       PG  31.0    6-0
# Aaron Gordon                  Orlando Magic     0.0       PF  20.0    6-9
# Aaron Harrison            Charlotte Hornets     9.0       SG  21.0    6-6
# Adreian Payne        Minnesota Timberwolves    33.0       PF  25.0   6-10
# Al Horford                    Atlanta Hawks    15.0        C  30.0   6-10
# ...                                     ...     ...      ...   ...    ...
# Willie Cauley-Stein        Sacramento Kings     0.0        C  22.0    7-0
# Willie Reed                   Brooklyn Nets    33.0       PF  26.0   6-10
# Wilson Chandler              Denver Nuggets    21.0       SF  29.0    6-8
# Zach LaVine          Minnesota Timberwolves     8.0       PG  21.0    6-5
# Zach Randolph             Memphis Grizzlies    50.0       PF  34.0    6-9
#
#                      Weight         College      Salary  Rank_salary
# ...

# %%
df.rename(mapper={"Aaron Brooks":"new Brooks"})
# Out:
#                                        Team  Number Position   Age Height  \
# Name
# new Brooks                    Chicago Bulls     0.0       PG  31.0    6-0
# Aaron Gordon                  Orlando Magic     0.0       PF  20.0    6-9
# Aaron Harrison            Charlotte Hornets     9.0       SG  21.0    6-6
# Adreian Payne        Minnesota Timberwolves    33.0       PF  25.0   6-10
# Al Horford                    Atlanta Hawks    15.0        C  30.0   6-10
# ...                                     ...     ...      ...   ...    ...
# Willie Cauley-Stein        Sacramento Kings     0.0        C  22.0    7-0
# Willie Reed                   Brooklyn Nets    33.0       PF  26.0   6-10
# Wilson Chandler              Denver Nuggets    21.0       SF  29.0    6-8
# Zach LaVine          Minnesota Timberwolves     8.0       PG  21.0    6-5
# Zach Randolph             Memphis Grizzlies    50.0       PF  34.0    6-9
#
#                      Weight         College      Salary  Rank_salary
# ...

# %%
df.sort_values(by="Salary")
# Out:
#                 Name                   Team  Number Position   Age Height  \
# 291  Orlando Johnson   New Orleans Pelicans     0.0       SG  27.0    6-5
# 130     Phil Pressey           Phoenix Suns    25.0       PG  25.0   5-11
# 135    Alan Williams           Phoenix Suns    15.0        C  23.0    6-8
# 175     Jordan McRae    Cleveland Cavaliers    12.0       SG  25.0    6-5
# 184    Lorenzo Brown        Detroit Pistons    17.0       PG  25.0    6-5
# ..               ...                    ...     ...      ...   ...    ...
# 164     Derrick Rose          Chicago Bulls     1.0       PG  27.0    6-3
# 414     Kevin Durant  Oklahoma City Thunder    35.0       SF  27.0    6-9
# 100       Chris Paul   Los Angeles Clippers     3.0       PG  31.0    6-0
# 339       Chris Bosh             Miami Heat     1.0       PF  32.0   6-11
# 33   Carmelo Anthony        New York Knicks     7.0       SF  32.0    6-8
#
#      Weight               College      Salary  Rank_salary
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 364 entries, Aaron Brooks to Zach Randolph
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Number       364 non-null    float64
#  1   Position     364 non-null    object
#  2   Age          364 non-null    float64
#  3   Height       364 non-null    object
#  4   Weight       364 non-null    float64
#  5   College      364 non-null    object
#  6   Salary       364 non-null    float64
#  7   Rank_salary  364 non-null    int32
# dtypes: float64(4), int32(1), object(3)
# memory usage: 32.3+ KB

# %%
df.sample(n=5)
# Out:
#                   Number Position   Age Height  Weight         College  \
# Name
# Luis Montero        44.0       SG  23.0    6-7   185.0  Westchester CC
# Ty Lawson           10.0       PG  28.0   5-11   195.0  North Carolina
# Trevor Ariza         1.0       SF  30.0    6-8   215.0            UCLA
# Dante Cunningham    44.0       PF  29.0    6-8   230.0       Villanova
# Kent Bazemore       24.0       SF  26.0    6-5   201.0    Old Dominion
#
#                      Salary  Rank_salary
# Name
# Luis Montero       525093.0           28
# Ty Lawson          211744.0           15
# Trevor Ariza      8193030.0          299
# Dante Cunningham  2850000.0          191
# Kent Bazemore     2000000.0          155

# %%
df.sample(frac=0.2)
# Out:
#                    Number Position   Age Height  Weight         College  \
# Name
# Anthony Brown         3.0       SF  23.0    6-7   210.0        Stanford
# Raymond Felton        2.0       PG  31.0    6-1   205.0  North Carolina
# James Anderson        5.0       SG  27.0    6-6   213.0  Oklahoma State
# Patrick Patterson    54.0       PF  27.0    6-9   235.0        Kentucky
# Terrence Ross        31.0       SF  25.0    6-7   195.0      Washington
# ...                   ...      ...   ...    ...     ...             ...
# Chris Andersen        7.0       PF  37.0   6-10   245.0   Blinn College
# Kyle O'Quinn          9.0       PF  26.0   6-10   250.0   Norfolk State
# Luke Babbitt          8.0       SF  26.0    6-9   225.0          Nevada
# Victor Oladipo        5.0       SG  24.0    6-4   210.0         Indiana
# Seth Curry           30.0       SG  25.0    6-2   185.0            Duke
#
#                       Salary  Rank_salary
# Name
# Anthony Brown       700000.0           38
# ...

# %%
df.nlargest(3,columns="Weight")
# Out:
#                 Number Position   Age Height  Weight      College      Salary  \
# Name
# Andre Drummond     0.0        C  22.0   6-11   279.0  Connecticut   3272091.0
# Brook Lopez       11.0        C  28.0    7-0   275.0     Stanford  19689000.0
# Jahlil Okafor      8.0        C  20.0   6-11   275.0         Duke   4582680.0
#
#                 Rank_salary
# Name
# Andre Drummond          211
# Brook Lopez             356
# Jahlil Okafor           246

# %%
# df.where()
df.query("Position == 'C'")
# Out:
#                      Number Position   Age Height  Weight  \
# Name
# Al Horford             15.0        C  30.0   6-10   245.0
# Alan Williams          15.0        C  23.0    6-8   260.0
# Alex Len               21.0        C  22.0    7-1   260.0
# Andre Drummond          0.0        C  22.0   6-11   279.0
# Andrew Bogut           12.0        C  31.0    7-0   260.0
# Aron Baynes            12.0        C  29.0   6-10   260.0
# Brook Lopez            11.0        C  28.0    7-0   275.0
# Chris Kaman            35.0        C  34.0    7-0   265.0
# Cody Zeller            40.0        C  23.0    7-0   240.0
# Cole Aldrich           45.0        C  27.0   6-11   250.0
# DeAndre Jordan          6.0        C  27.0   6-11   265.0
# DeMarcus Cousins       15.0        C  25.0   6-11   270.0
# Dewayne Dedmon          3.0        C  26.0    7-0   245.0
# Ed Davis               17.0        C  27.0   6-10   240.0
# Enes Kanter            11.0        C  24.0   6-11   245.0
# ...

# %%
for data in df.columns:
    print(data)
    
type(df.columns)
# Out:
# Number
# Position
# Age
# Height
# Weight
# College
# Salary
# Rank_salary
# pandas.core.indexes.base.Index

# %%
df.columns=["hey"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [77], line 1
# ----> 1 df.columns=["hey"]
#
# File c:\users\tushar\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py:5915, in NDFrame.__setattr__(self, name, value)
#    5913 try:
#    5914     object.__getattribute__(self, name)
# -> 5915     return object.__setattr__(self, name, value)
#    5916 except AttributeError:
#    5917     pass
#
# File c:\users\tushar\appdata\local\programs\python\python38\lib\site-packages\pandas\_libs\properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\users\tushar\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py:823, in NDFrame._set_axis(self, axis, labels)
#     821 def _set_axis(self, axis: int, labels: AnyArrayLike | list) -> None:
#     822     labels = ensure_index(labels)
# ...

# %%
df2 = pd.read_csv("NbaInfo.csv", usecols=["Name"])

# %%
df2.columns=["Data"]

# %%
df2
# Out:
#               Data
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# ..             ...
# 453   Shelvin Mack
# 454      Raul Neto
# 455   Tibor Pleiss
# 456    Jeff Withey
# 457            NaN
#
# [458 rows x 1 columns]
