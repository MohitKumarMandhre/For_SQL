# %%
import pandas as pd

# %%
df = pd.read_csv("pokemon_data.csv", usecols=["Pokemon"]).squeeze()

PokemonSeries = pd.read_csv("pokemon_data.csv", usecols=["Pokemon"]).squeeze()

# %%
PokemonSeries
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 716       Yveltal
# 717       Zygarde
# 718       Diancie
# 719         Hoopa
# 720     Volcanion
# Name: Pokemon, Length: 721, dtype: object

# %%
len(PokemonSeries)
max(PokemonSeries)
min(PokemonSeries)
# Out:
# 'Abomasnow'

# %%
PokemonSeries
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 716       Yveltal
# 717       Zygarde
# 718       Diancie
# 719         Hoopa
# 720     Volcanion
# Name: Pokemon, Length: 721, dtype: object

# %%
dict(PokemonSeries)
# Out:
# {0: 'Bulbasaur',
#  1: 'Ivysaur',
#  2: 'Venusaur',
#  3: 'Charmander',
#  4: 'Charmeleon',
#  5: 'Charizard',
#  6: 'Squirtle',
#  7: 'Wartortle',
#  8: 'Blastoise',
#  9: 'Caterpie',
#  10: 'Metapod',
#  11: 'Butterfree',
#  12: 'Weedle',
#  13: 'Kakuna',
#  14: 'Beedrill',
#  15: 'Pidgey',
#  16: 'Pidgeotto',
#  17: 'Pidgeot',
#  18: 'Rattata',
#  19: 'Raticate',
#  20: 'Spearow',
#  21: 'Fearow',
#  22: 'Ekans',
#  23: 'Arbok',
#  24: 'Pikachu',
#  25: 'Raichu',
#  26: 'Sandshrew',
#  27: 'Sandslash',
#  28: 'Nidoran',
#  29: 'Nidorina',
#  30: 'Nidoqueen',
#  31: 'Nidoran♂',
#  32: 'Nidorino',
#  33: 'Nidoking',
#  34: 'Clefairy',
#  35: 'Clefable',
#  36: 'Vulpix',
#  37: 'Ninetales',
#  38: 'Jigglypuff',
#  39: 'Wigglytuff',
#  40: 'Zubat',
#  41: 'Golbat',
#  42: 'Oddish',
#  43: 'Gloom',
#  44: 'Vileplume',
#  45: 'Paras',
#  46: 'Parasect',
#  47: 'Venonat',
#  48: 'Venomoth',
#  49: 'Diglett',
#  50: 'Dugtrio',
#  51: 'Meowth',
#  52: 'Persian',
#  53: 'Psyduck',
# ...

# %%
type(sorted(PokemonSeries))
# Out:
# list

# %%
PokemonSeries.sort_values(ignore_index=True,ascending=False).tail()
# Out:
# 716    Aegislash
# 717     Accelgor
# 718        Absol
# 719         Abra
# 720    Abomasnow
# Name: Pokemon, dtype: object

# %%
df = pd.read_csv("pokemon_data.csv", usecols=["Pokemon"])

typeSeries = df.squeeze().copy()

# %%
df
# Out:
#         Pokemon
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# ..          ...
# 716     Yveltal
# 717     Zygarde
# 718     Diancie
# 719       Hoopa
# 720   Volcanion
#
# [721 rows x 1 columns]

# %%
typeSeries.sort_index()
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 716       Yveltal
# 717       Zygarde
# 718       Diancie
# 719         Hoopa
# 720     Volcanion
# Name: Pokemon, Length: 721, dtype: object

# %%
PokemonSeries[[0,2,4,7]]

# %%
PokemonSeries[[0,4,7]]

# %%
typeSeries.get(72666,"hELP")
# Out:
# 'hELP'

# %%
typeSeries[[0,1]]=["Water","Fire"]

typeSeries
# Out:
# 0           Water
# 1            Fire
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 716       Yveltal
# 717       Zygarde
# 718       Diancie
# 719         Hoopa
# 720     Volcanion
# Name: Pokemon, Length: 721, dtype: object

# %%
df
# Out:
#         Pokemon
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# ..          ...
# 716     Yveltal
# 717     Zygarde
# 718     Diancie
# 719       Hoopa
# 720   Volcanion
#
# [721 rows x 1 columns]

# %%
typeSeries.head(2)
# Out:
# 0    Water
# 1     Fire
# Name: Pokemon, dtype: object

# %%
myDictionary={"Water":"happy",
           "Fire":"Angry",
        "Venusaur" : "Sad"}

# %%
typeSeries.map(myDictionary)
# Out:
# 0      happy
# 1      Angry
# 2        Sad
# 3        NaN
# 4        NaN
#        ...
# 716      NaN
# 717      NaN
# 718      NaN
# 719      NaN
# 720      NaN
# Name: Pokemon, Length: 721, dtype: object

# %%
typeSeries
# Out:
# 0           Water
# 1            Fire
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 716       Yveltal
# 717       Zygarde
# 718       Diancie
# 719         Hoopa
# 720     Volcanion
# Name: Pokemon, Length: 721, dtype: object
