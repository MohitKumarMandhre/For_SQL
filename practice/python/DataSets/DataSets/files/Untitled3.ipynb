# %%
import pandas as pd

# %%
df = pd.read_csv("BigmacBurger_data.csv",parse_dates=["Date"],index_col=["Date","Country"])

# %%
df.rename(mapper={"Jan-16":"hey"})

# get level values
# Out:
#                       Price in US Dollars
# Date   Country
# hey    Argentina                     2.39
#        Australia                     3.74
#        Brazil                        3.35
#        Britain                       4.22
#        Canada                        4.14
# ...                                   ...
# Jan-10 UAE                           2.99
#        Ukraine                       1.83
#        United States                 3.58
#        Uruguay                       3.32
#        Urgu                          3.32
#
# [653 rows x 1 columns]

# %%
df.swaplevel()
# Out:
#                       Price in US Dollars
# Country       Date
# Argentina     Jan-16                 2.39
# Australia     Jan-16                 3.74
# Brazil        Jan-16                 3.35
# Britain       Jan-16                 4.22
# Canada        Jan-16                 4.14
# ...                                   ...
# UAE           Jan-10                 2.99
# Ukraine       Jan-10                 1.83
# United States Jan-10                 3.58
# Uruguay       Jan-10                 3.32
# Urgu          Jan-10                 3.32
#
# [653 rows x 1 columns]

# %%
df
# Out:
#                       Price in US Dollars
# Date   Country
# Jan-16 Argentina                     2.39
#        Australia                     3.74
#        Brazil                        3.35
#        Britain                       4.22
#        Canada                        4.14
# ...                                   ...
# Jan-10 UAE                           2.99
#        Ukraine                       1.83
#        United States                 3.58
#        Uruguay                       3.32
#        Urgu                          3.32
#
# [653 rows x 1 columns]

# %%
df.loc[("Jan-16","Argentina")]
# Out:
# Price in US Dollars    2.39
# Name: (Jan-16, Argentina), dtype: float64

# %%
df.index.get_level_values(0)
# Out:
# Index(['Jan-16', 'Jan-16', 'Jan-16', 'Jan-16', 'Jan-16', 'Jan-16', 'Jan-16',
#        'Jan-16', 'Jan-16', 'Jan-16',
#        ...
#        'Jan-10', 'Jan-10', 'Jan-10', 'Jan-10', 'Jan-10', 'Jan-10', 'Jan-10',
#        'Jan-10', 'Jan-10', 'Jan-10'],
#       dtype='object', name='Date', length=653)

# %%
df.loc[   ("Jan-16",) ].loc["Argentina":"Canada"]
# Out:
# C:\Users\Tushar\AppData\Local\Temp\ipykernel_13628\2049270490.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df.loc[   ("Jan-16",) ].loc["Argentina":"Canada"]
#            Price in US Dollars
# Country
# Argentina                 2.39
# Australia                 3.74
# Brazil                    3.35
# Britain                   4.22
# Canada                    4.14

# %%
df.index.get_level_values(0)
# Out:
# Index(['Jan-16', 'Jan-16', 'Jan-16', 'Jan-16', 'Jan-16', 'Jan-16', 'Jan-16',
#        'Jan-16', 'Jan-16', 'Jan-16',
#        ...
#        'Jan-10', 'Jan-10', 'Jan-10', 'Jan-10', 'Jan-10', 'Jan-10', 'Jan-10',
#        'Jan-10', 'Jan-10', 'Jan-10'],
#       dtype='object', name='Date', length=653)

# %%
df
# Out:
#                       Price in US Dollars
# Date   Country
# Jan-16 Argentina                     2.39
#        Australia                     3.74
#        Brazil                        3.35
#        Britain                       4.22
#        Canada                        4.14
# ...                                   ...
# Jan-10 UAE                           2.99
#        Ukraine                       1.83
#        United States                 3.58
#        Uruguay                       3.32
#        Urgu                          3.32
#
# [653 rows x 1 columns]

# %%
df2 = df.transpose()

df2
# Out:
# Date                   Jan-16                                              \
# Country             Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars      2.39      3.74   3.35    4.22   4.14  2.94  2.68
#
# Date                                                    ... Jan-10  \
# Country             Colombia Costa Rica Czech Republic  ... Sweden
# Price in US Dollars     2.43       4.02           2.98  ...   5.51
#
# Date                                                                  \
# Country             Switzerland Taiwan Thailand Turkey   UAE Ukraine
# Price in US Dollars         6.3   2.36     2.11   3.83  2.99    1.83
#
# Date
# Country             United States Uruguay  Urgu
# Price in US Dollars          3.58    3.32  3.32
#
# [1 rows x 653 columns]

# %%
df2.loc["Price in US Dollars","Jan-16"]["Brazil"]
# Out:
# 3.35

# %%
df

df.index
# Out:
# MultiIndex([('Jan-16',      'Argentina'),
#             ('Jan-16',      'Australia'),
#             ('Jan-16',         'Brazil'),
#             ('Jan-16',        'Britain'),
#             ('Jan-16',         'Canada'),
#             ('Jan-16',          'Chile'),
#             ('Jan-16',          'China'),
#             ('Jan-16',       'Colombia'),
#             ('Jan-16',     'Costa Rica'),
#             ('Jan-16', 'Czech Republic'),
#             ...
#             ('Jan-10',         'Sweden'),
#             ('Jan-10',    'Switzerland'),
#             ('Jan-10',         'Taiwan'),
#             ('Jan-10',       'Thailand'),
#             ('Jan-10',         'Turkey'),
#             ('Jan-10',            'UAE'),
#             ('Jan-10',        'Ukraine'),
#             ('Jan-10',  'United States'),
#             ('Jan-10',        'Uruguay'),
#             ('Jan-10',           'Urgu')],
#            names=['Date', 'Country'], length=653)

# %%
df.index.set_names(names=["Dayss","Valuess"])
# Out:
# MultiIndex([('Jan-16',      'Argentina'),
#             ('Jan-16',      'Australia'),
#             ('Jan-16',         'Brazil'),
#             ('Jan-16',        'Britain'),
#             ('Jan-16',         'Canada'),
#             ('Jan-16',          'Chile'),
#             ('Jan-16',          'China'),
#             ('Jan-16',       'Colombia'),
#             ('Jan-16',     'Costa Rica'),
#             ('Jan-16', 'Czech Republic'),
#             ...
#             ('Jan-10',         'Sweden'),
#             ('Jan-10',    'Switzerland'),
#             ('Jan-10',         'Taiwan'),
#             ('Jan-10',       'Thailand'),
#             ('Jan-10',         'Turkey'),
#             ('Jan-10',            'UAE'),
#             ('Jan-10',        'Ukraine'),
#             ('Jan-10',  'United States'),
#             ('Jan-10',        'Uruguay'),
#             ('Jan-10',           'Urgu')],
#            names=['Dayss', 'Valuess'], length=653)

# %%
df
# Out:
#                       Price in US Dollars
# Date   Country
# Jan-16 Argentina                     2.39
#        Australia                     3.74
#        Brazil                        3.35
#        Britain                       4.22
#        Canada                        4.14
# ...                                   ...
# Jan-10 UAE                           2.99
#        Ukraine                       1.83
#        United States                 3.58
#        Uruguay                       3.32
#        Urgu                          3.32
#
# [653 rows x 1 columns]

# %%
df3 = pd.read_csv("BigmacBurger_data.csv",index_col=["Date"])

# %%
df3.head()
# Out:
#           Country  Price in US Dollars
# Date
# Jan-16  Argentina                 2.39
# Jan-16  Australia                 3.74
# Jan-16     Brazil                 3.35
# Jan-16    Britain                 4.22
# Jan-16     Canada                 4.14

# %%
df3.stack().unstack()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [101], line 1
# ----> 1 df3.stack().unstack()
#
# File c:\users\tushar\appdata\local\programs\python\python38\lib\site-packages\pandas\core\series.py:4455, in Series.unstack(self, level, fill_value)
#    4412 """
#    4413 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4414
#    (...)
#    4451 b    2    4
#    4452 """
#    4453 from pandas.core.reshape.reshape import unstack
# -> 4455 return unstack(self, level, fill_value)
#
# File c:\users\tushar\appdata\local\programs\python\python38\lib\site-packages\pandas\core\reshape\reshape.py:489, in unstack(obj, level, fill_value)
#     487 if is_1d_only_ea_dtype(obj.dtype):
#     488     return _unstack_extension_series(obj, level, fill_value)
# --> 489 unstacker = _Unstacker(
# ...

# %%
s = df3.stack()

# %%
df3.unstack()
# Out:
#                      Date
# Country              Jan-16    Argentina
#                      Jan-16    Australia
#                      Jan-16       Brazil
#                      Jan-16      Britain
#                      Jan-16       Canada
#                                  ...
# Price in US Dollars  Jan-10         2.99
#                      Jan-10         1.83
#                      Jan-10         3.58
#                      Jan-10         3.32
#                      Jan-10         3.32
# Length: 1306, dtype: object

# %%
df3.columns
# Out:
# Index(['Country', 'Price in US Dollars'], dtype='object')

# %%
df
# Out:
#        Date        Country  Price in US Dollars
# 0    Jan-16      Argentina                 2.39
# 1    Jan-16      Australia                 3.74
# 2    Jan-16         Brazil                 3.35
# 3    Jan-16        Britain                 4.22
# 4    Jan-16         Canada                 4.14
# ..      ...            ...                  ...
# 648  Jan-10            UAE                 2.99
# 649  Jan-10        Ukraine                 1.83
# 650  Jan-10  United States                 3.58
# 651  Jan-10        Uruguay                 3.32
# 652  Jan-10           Urgu                 3.32
#
# [653 rows x 3 columns]

# %%
df = pd.read_csv("BigmacBurger_data.csv")
df.columns
df
df.pivot(index="Date", columns="Country",values="Price in US Dollars")
# Out:
# Country  Argentina  Australia  Austria  Belgium  Brazil  Britain  Canada  \
# Date
# Jan-10        1.84       3.98      NaN      NaN    4.76     3.67    3.97
# Jan-12        4.64       4.94     3.92     4.69    5.68     3.82    4.63
# Jan-13        3.82       4.90     4.60     5.16    5.64     4.25    5.39
# Jan-14        3.03       4.47     4.60     5.36    5.25     4.63    5.01
# Jan-15        3.25       4.32     3.93     4.29    5.21     4.37    4.64
# Jan-16        2.39       3.74     3.76     4.25    3.35     4.22    4.14
# Jul-10        3.56       3.84      NaN      NaN    4.91     3.48    4.00
# Jul-11        4.84       4.94     4.43     5.38    6.16     3.89    5.00
# Jul-12        4.16       4.68     3.87     4.61    4.94     4.16    5.02
# Jul-13        3.88       4.62     4.36     4.76    5.28     4.02    5.26
# Jul-14        2.57       4.81     4.56     4.98    5.86     4.93    5.25
# Jul-15        3.07       3.92     3.71     4.05    4.28     4.51    4.54
#
# ...
