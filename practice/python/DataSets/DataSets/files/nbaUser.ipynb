# %%
import pandas as pd

df = pd.read_csv("NbaInfo.csv")

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df[["Name","Team"]]
# Out:
#               Name            Team
# 0    Avery Bradley  Boston Celtics
# 1      Jae Crowder  Boston Celtics
# 2     John Holland  Boston Celtics
# 3      R.J. Hunter  Boston Celtics
# 4    Jonas Jerebko  Boston Celtics
# ..             ...             ...
# 453   Shelvin Mack       Utah Jazz
# 454      Raul Neto       Utah Jazz
# 455   Tibor Pleiss       Utah Jazz
# 456    Jeff Withey       Utah Jazz
# 457            NaN             NaN
#
# [458 rows x 2 columns]

# %%
df["Email"]="user@gmail.com"

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary           Email
# ...

# %%
df.insert(2,"WeightUser2",80)

# %%
df
# Out:
#               Name  WeightUser  WeightUser2            Team  Number Position  \
# 0    Avery Bradley          80           80  Boston Celtics     0.0       PG
# 1      Jae Crowder          80           80  Boston Celtics    99.0       SF
# 2     John Holland          80           80  Boston Celtics    30.0       SG
# 3      R.J. Hunter          80           80  Boston Celtics    28.0       SG
# 4    Jonas Jerebko          80           80  Boston Celtics     8.0       PF
# ..             ...         ...          ...             ...     ...      ...
# 453   Shelvin Mack          80           80       Utah Jazz     8.0       PG
# 454      Raul Neto          80           80       Utah Jazz    25.0       PG
# 455   Tibor Pleiss          80           80       Utah Jazz    21.0        C
# 456    Jeff Withey          80           80       Utah Jazz    24.0        C
# 457            NaN          80           80             NaN     NaN      NaN
#
# ...

# %%
df["newage"] = df["Age"]+4

# %%
df
# Out:
#               Name  WeightUser  WeightUser2            Team  Number Position  \
# 0    Avery Bradley          80           80  Boston Celtics     0.0       PG
# 1      Jae Crowder          80           80  Boston Celtics    99.0       SF
# 2     John Holland          80           80  Boston Celtics    30.0       SG
# 3      R.J. Hunter          80           80  Boston Celtics    28.0       SG
# 4    Jonas Jerebko          80           80  Boston Celtics     8.0       PF
# ..             ...         ...          ...             ...     ...      ...
# 453   Shelvin Mack          80           80       Utah Jazz     8.0       PG
# 454      Raul Neto          80           80       Utah Jazz    25.0       PG
# 455   Tibor Pleiss          80           80       Utah Jazz    21.0        C
# 456    Jeff Withey          80           80       Utah Jazz    24.0        C
# 457            NaN          80           80             NaN     NaN      NaN
#
# ...

# %%
df.value_counts(subset="Team",normalize=True)*100
# Out:
# Team
# New Orleans Pelicans      4.157549
# Memphis Grizzlies         3.938731
# New York Knicks           3.501094
# Milwaukee Bucks           3.501094
# Atlanta Hawks             3.282276
# Utah Jazz                 3.282276
# Toronto Raptors           3.282276
# San Antonio Spurs         3.282276
# Sacramento Kings          3.282276
# Portland Trail Blazers    3.282276
# Phoenix Suns              3.282276
# Philadelphia 76ers        3.282276
# Oklahoma City Thunder     3.282276
# Boston Celtics            3.282276
# Miami Heat                3.282276
# Los Angeles Lakers        3.282276
# Los Angeles Clippers      3.282276
# Indiana Pacers            3.282276
# Houston Rockets           3.282276
# Golden State Warriors     3.282276
# Detroit Pistons           3.282276
# Denver Nuggets            3.282276
# Dallas Mavericks          3.282276
# Cleveland Cavaliers       3.282276
# Chicago Bulls             3.282276
# Charlotte Hornets         3.282276
# ...

# %%
df
# Out:
#               Name  WeightUser  WeightUser2            Team  Number Position  \
# 0    Avery Bradley          80           80  Boston Celtics     0.0       PG
# 1      Jae Crowder          80           80  Boston Celtics    99.0       SF
# 2     John Holland          80           80  Boston Celtics    30.0       SG
# 3      R.J. Hunter          80           80  Boston Celtics    28.0       SG
# 4    Jonas Jerebko          80           80  Boston Celtics     8.0       PF
# ..             ...         ...          ...             ...     ...      ...
# 453   Shelvin Mack          80           80       Utah Jazz     8.0       PG
# 454      Raul Neto          80           80       Utah Jazz    25.0       PG
# 455   Tibor Pleiss          80           80       Utah Jazz    21.0        C
# 456    Jeff Withey          80           80       Utah Jazz    24.0        C
# 457            NaN          80           80             NaN     NaN      NaN
#
# ...

# %%
df.value_counts()
# Out:
# Name                    WeightUser  WeightUser2  Team                   Number  Position  Age   Height  Weight  College         Salary      Email           newage
# Aaron Brooks            80          80           Chicago Bulls          0.0     PG        31.0  6-0     161.0   Oregon          2250000.0   user@gmail.com  35.0      1
# Mike Muscala            80          80           Atlanta Hawks          31.0    PF        24.0  6-11    240.0   Bucknell        947276.0    user@gmail.com  28.0      1
# Mike Dunleavy           80          80           Chicago Bulls          34.0    SG        35.0  6-9     230.0   Duke            4500000.0   user@gmail.com  39.0      1
# Mike Conley             80          80           Memphis Grizzlies      11.0    PG        28.0  6-1     175.0   Ohio State      9588426.0   user@gmail.com  32.0      1
# ...

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df["Name"].hasnans

df.dropna(how="any")
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %%
df.dropna(how="all")
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.dropna(subset=["College","Salary"],inplace=True)
# df =df.dropna(subset=["College","Salary"])

# %%
df2
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
# dropna
df["Salary"]=df["Salary"].fillna(0)

df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# fillna

df["Salary"].hasnans
# Out:
# False

# %%
df.fillna("Unknown",inplace=True)

# sort_value()
df.sort_values(by=["Team","Name"],ascending=[False,True],na_position="first")
# Out:
#                  Name                Team Number Position   Age Height Weight  \
# 368     Alan Anderson  Washington Wizards    6.0       SG  33.0    6-6  220.0
# 369      Bradley Beal  Washington Wizards    3.0       SG  22.0    6-5  207.0
# 372       Drew Gooden  Washington Wizards   90.0       PF  34.0   6-10  250.0
# 380    Garrett Temple  Washington Wizards   17.0       SG  30.0    6-6  195.0
# 374        JJ Hickson  Washington Wizards   21.0        C  27.0    6-9  242.0
# ..                ...                 ...    ...      ...   ...    ...    ...
# 315      Paul Millsap       Atlanta Hawks    4.0       PF  31.0    6-8  246.0
# 320   Thabo Sefolosha       Atlanta Hawks   25.0       SF  32.0    6-7  220.0
# 321    Tiago Splitter       Atlanta Hawks   11.0        C  31.0   6-11  245.0
# 310  Tim Hardaway Jr.       Atlanta Hawks   10.0       SG  24.0    6-6  205.0
# 322    Walter Tavares       Atlanta Hawks   22.0        C  24.0    7-3  260.0
#
# ...

# %%
df["Salary"].astype(int)
# Out:
# 0      7730337
# 1      6796117
# 2            0
# 3      1148640
# 4      5000000
#         ...
# 453    2433333
# 454     900000
# 455    2900000
# 456     947276
# 457          0
# Name: Salary, Length: 458, dtype: int32

# %%
# df["Age"].info()

# df["Age"].hasnans

df["Age"]=df["Age"].fillna(0)
df["Salary"]=df["Salary"].fillna(0)

# %%
df["Age"].hasnans
# Out:
# False

# %%
df["Age"]=df["Age"].astype(int)
df["Salary"]=df["Age"].astype(int)

# %%
df["Team"].nunique()
# Out:
# 30

# %%
df["Team"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 458 entries, 0 to 457
# Series name: Team
# Non-Null Count  Dtype
# --------------  -----
# 457 non-null    object
# dtypes: object(1)
# memory usage: 3.7+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       458 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    458 non-null    int32
# dtypes: float64(2), int32(2), object(5)
# memory usage: 28.8+ KB

# %%
df["Team"]=df["Team"].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    category
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       458 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    458 non-null    int32
# dtypes: category(1), float64(2), int32(2), object(4)
# memory usage: 26.9+ KB

# %%
df["Salary"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 458 entries, 0 to 457
# Series name: Salary
# Non-Null Count  Dtype
# --------------  -----
# 458 non-null    int64
# dtypes: int64(1)
# memory usage: 3.7 KB

# %%
# converting data type using astype method

# %%
# muti column sorting using sort_value[by=[col1,col2]]

# %%
#  to check null value present .hasnans

# %%
#  to see all unique values

# %%
# readcsv

# %%
ds = pd.read_csv("jamesbond_user.csv",index_col="Film")

# %%
ds
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...
