# %%
import pandas as pd

# %%
df = pd.read_csv("fortune_data.csv")
df.head(3)
# Out:
#    Rank      Company      Sector                     Industry  \
# 0     1      Walmart   Retailing        General Merchandisers
# 1     2  Exxon Mobil      Energy           Petroleum Refining
# 2     3        Apple  Technology  Computers, Office Equipment
#
#           Location  Revenue  Profits  Employees
# 0  Bentonville, AR   482130    14694    2300000
# 1       Irving, TX   246204    16150      75600
# 2    Cupertino, CA   233715    53394     110000

# %%
df["Rank"].nunique()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rank       1000 non-null   int64
#  1   Company    1000 non-null   object
#  2   Sector     1000 non-null   object
#  3   Industry   1000 non-null   object
#  4   Location   1000 non-null   object
#  5   Revenue    1000 non-null   int64
#  6   Profits    1000 non-null   int64
#  7   Employees  1000 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 62.6+ KB

# %%
df["Sector"].nunique()
# Out:
# 21

# %%
df["Industry"].nunique()
# Out:
# 73

# %%
len(sector_group)
# Out:
# 21

# %%
df["Sector"].nunique()
# Out:
# 21

# %%
sector_group = df.groupby("Sector")

# %%
df.iloc[90]
# Out:
# Rank                    91
# Company               Nike
# Sector             Apparel
# Industry           Apparel
# Location     Beaverton, OR
# Revenue              30601
# Profits               3273
# Employees            62600
# Name: 90, dtype: object

# %%
sector_group.groups
# Out:
# {'Aerospace & Defense': [23, 44, 59, 87, 117, 119, 208, 244, 281, 377, 388, 489, 559, 604, 784, 787, 835, 902, 957, 986], 'Apparel': [90, 230, 339, 353, 447, 546, 574, 596, 682, 694, 725, 793, 876, 881, 916], 'Business Services': [143, 185, 198, 203, 220, 247, 248, 293, 306, 311, 354, 391, 403, 439, 466, 467, 480, 484, 491, 502, 544, 625, 634, 651, 676, 693, 713, 728, 733, 734, 736, 743, 766, 775, 776, 782, 790, 791, 795, 800, 802, 815, 818, 819, 868, 869, 885, 938, 950, 951, 992], 'Chemicals': [55, 100, 181, 188, 205, 252, 261, 276, 287, 295, 315, 537, 548, 554, 565, 579, 612, 623, 653, 667, 716, 719, 723, 757, 760, 828, 864, 897, 933, 948], 'Energy': [1, 13, 29, 31, 41, 64, 89, 94, 97, 103, 114, 116, 120, 161, 162, 164, 165, 174, 177, 187, 189, 191, 192, 197, 213, 215, 216, 222, 224, 228, 242, 245, 246, 256, 271, 273, 278, 288, 318, 321, 323, 342, 347, 348, 349, 362, 363, 383, 386, 387, 393, 401, 402, 409, 424, 436, 437, 444, 457, 474, 482, 492, 506, 521, 540, 547, 555, 557, 568, 5
# ...

# %%
sector_group.size()
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %%
df
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
df["Sector"].value_counts()
# Out:
# Financials                      139
# Energy                          122
# Technology                      102
# Retailing                        80
# Health Care                      75
# Business Services                51
# Industrials                      46
# Materials                        43
# Food, Beverages & Tobacco        43
# Wholesalers                      40
# Transportation                   36
# Chemicals                        30
# Household Products               28
# Engineering & Construction       26
# Media                            25
# Hotels, Resturants & Leisure     25
# Motor Vehicles & Parts           24
# Aerospace & Defense              20
# Telecommunications               15
# Apparel                          15
# Food and Drug Stores             15
# Name: Sector, dtype: int64

# %%
sector_group.get_group("Media")
# Out:
#      Rank                       Company Sector              Industry  \
# 52     53                        Disney  Media         Entertainment
# 95     96      Twenty-First Century Fox  Media         Entertainment
# 98     99                   Time Warner  Media         Entertainment
# 202   203                           CBS  Media         Entertainment
# 212   213                        Viacom  Media         Entertainment
# 254   255         R.R. Donnelley & Sons  Media  Publishing, Printing
# 326   327                    News Corp.  Media  Publishing, Printing
# 365   366     Live Nation Entertainment  Media         Entertainment
# 405   406      Discovery Communications  Media         Entertainment
# 413   414                   iHeartMedia  Media         Entertainment
# 524   525                 Liberty Media  Media         Entertainment
# 529   530                 Quad/Graphics  Media  Publishing, Printing
# 680   681                         TEGNA  Media         Entertainment
# ...

# %%
sector_group.first()
# Out:
#                               Rank                 Company  \
# Sector
# Aerospace & Defense             24                  Boeing
# Apparel                         91                    Nike
# Business Services              144           ManpowerGroup
# Chemicals                       56            Dow Chemical
# Energy                           2             Exxon Mobil
# Engineering & Construction     155                   Fluor
# Financials                       4      Berkshire Hathaway
# Food and Drug Stores             7              CVS Health
# Food, Beverages & Tobacco       41  Archer Daniels Midland
# Health Care                      5                McKesson
# Hotels, Resturants & Leisure   109              McDonald’s
# Household Products              34        Procter & Gamble
# Industrials                     11        General Electric
# Materials                      126                   Alcoa
# Media                           53                  Disney
# ...

# %%
sector_group.get_group("Aerospace & Defense",)
# Out:
#      Rank                        Company               Sector  \
# 23     24                         Boeing  Aerospace & Defense
# 44     45            United Technologies  Aerospace & Defense
# 59     60                Lockheed Martin  Aerospace & Defense
# 87     88               General Dynamics  Aerospace & Defense
# 117   118               Northrop Grumman  Aerospace & Defense
# 119   120                       Raytheon  Aerospace & Defense
# 208   209                        Textron  Aerospace & Defense
# 244   245             L-3 Communications  Aerospace & Defense
# 281   282            Precision Castparts  Aerospace & Defense
# 377   378  Huntington Ingalls Industries  Aerospace & Defense
# 388   389    Spirit AeroSystems Holdings  Aerospace & Defense
# 489   490               Rockwell Collins  Aerospace & Defense
# 559   560                    Orbital ATK  Aerospace & Defense
# 604   605                  Triumph Group  Aerospace & Defense
# ...

# %%
df [ df["Sector"]=="Energy" ]["Profits"]
# Out:
# 1      16150
# 13      4587
# 29      4227
# 31      3990
# 41      2852
#        ...
# 980    -1727
# 982       -1
# 994    -3748
# 996      172
# 997      172
# Name: Profits, Length: 122, dtype: int64

# %%
sector_group.get_group("Energy")
# Out:
#      Rank                    Company  Sector                      Industry  \
# 1       2                Exxon Mobil  Energy            Petroleum Refining
# 13     14                    Chevron  Energy            Petroleum Refining
# 29     30                Phillips 66  Energy            Petroleum Refining
# 31     32              Valero Energy  Energy            Petroleum Refining
# 41     42         Marathon Petroleum  Energy            Petroleum Refining
# ..    ...                        ...     ...                           ...
# 980   981                 WPX Energy  Energy  Mining, Crude-Oil Production
# 982   983   Adams Resources & Energy  Energy            Petroleum Refining
# 994   995                  EP Energy  Energy  Mining, Crude-Oil Production
# 996   997  Portland General Electric  Energy   Utilities: Gas and Electric
# 997   997  Portland General Electric  Energy   Utilities: Gas and Electric
#
#             Location  Revenue  Profits  Employees
# ...

# %%
sector_group.max()
# Out:
#                               Rank                 Company  \
# Sector
# Aerospace & Defense            987                Woodward
# Apparel                        917    Wolverine World Wide
# Business Services              993           Western Union
# Chemicals                      949       Westlake Chemical
# Energy                         997             Xcel Energy
# Engineering & Construction     994            Tutor Perini
# Financials                     996          Zions Bancorp.
# Food and Drug Stores           928      Whole Foods Market
# Food, Beverages & Tobacco      954         WhiteWave Foods
# Health Care                    978         inVentiv Health
# Hotels, Resturants & Leisure   999              Yum Brands
# Household Products             992           Vista Outdoor
# Industrials                   1000      Zebra Technologies
# Materials                      986  Worthington Industries
# Media                          989             iHeartMedia
# ...

# %%
sector_group.min()
# Out:
#                               Rank                        Company  \
# Sector
# Aerospace & Defense             24                  B/E Aerospace
# Apparel                         91                       Carter’s
# Business Services              144                 ABM Industries
# Chemicals                       56                    A. Schulman
# Energy                           2                            AES
# Engineering & Construction     155                          AECOM
# Financials                       4                            AIG
# Food and Drug Stores             7                     CVS Health
# Food, Beverages & Tobacco       41     Alliance One International
# Health Care                      5                         AbbVie
# Hotels, Resturants & Leisure   109                Bloomin’ Brands
# Household Products              34                  Avon Products
# Industrials                     11                             3M
# ...

# %%
sector_group["Profits"].max().get("Energy")
# Out:
# 16150

# %%
sectorNew = df.groupby([ "Sector","Industry"])

# %%
sectorNew.groups
# Out:
# {('Aerospace & Defense', 'Aerospace and Defense'): [23, 44, 59, 87, 117, 119, 208, 244, 281, 377, 388, 489, 559, 604, 784, 787, 835, 902, 957, 986], ('Apparel', 'Apparel'): [90, 230, 339, 353, 447, 546, 574, 596, 682, 694, 725, 793, 876, 881, 916], ('Business Services', 'Advertising, marketing'): [185, 354], ('Business Services', 'Diversified Outsourcing Services'): [198, 247, 484, 544, 625, 634, 713, 728, 743, 782, 802, 815, 818, 868], ('Business Services', 'Education'): [736, 819, 992], ('Business Services', 'Financial Data Services'): [203, 248, 293, 306, 391, 403, 467, 480, 491, 651, 693, 766, 775, 776, 791, 795, 800, 885, 951], ('Business Services', 'Miscellaneous'): [439, 733, 869], ('Business Services', 'Temporary Help'): [143, 466, 502, 790, 950], ('Business Services', 'Waste Management'): [220, 311, 676, 734, 938], ('Chemicals', 'Chemicals'): [55, 100, 181, 188, 205, 252, 261, 276, 287, 295, 315, 537, 548, 554, 565, 579, 612, 623, 653, 667, 716, 719, 723, 757, 760, 828, 864,
# ...

# %%
sectorNew.get_group( ("Energy","Petroleum Refining") )
# Out:
#      Rank                              Company  Sector            Industry  \
# 1       2                          Exxon Mobil  Energy  Petroleum Refining
# 13     14                              Chevron  Energy  Petroleum Refining
# 29     30                          Phillips 66  Energy  Petroleum Refining
# 31     32                        Valero Energy  Energy  Petroleum Refining
# 41     42                   Marathon Petroleum  Energy  Petroleum Refining
# 97     98                               Tesoro  Energy  Petroleum Refining
# 213   214                        HollyFrontier  Energy  Petroleum Refining
# 216   217                           PBF Energy  Energy  Petroleum Refining
# 288   289                     Western Refining  Energy  Petroleum Refining
# 393   394                                 Hess  Energy  Petroleum Refining
# 444   445                    Delek US Holdings  Energy  Petroleum Refining
# ...

# %%
sectorNew.size()
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense                            20
# Apparel              Apparel                                          15
# Business Services    Advertising, marketing                            2
#                      Diversified Outsourcing Services                 14
#                      Education                                         3
#                                                                       ..
# Transportation       Trucking, Truck Leasing                           9
# Wholesalers          Miscellaneous                                     1
#                      Wholesalers: Diversified                         25
#                      Wholesalers: Electronics and Office Equipment     8
#                      Wholesalers: Food and Grocery                     6
# Length: 79, dtype: int64

# %%
sector_group.size()
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %%
sectorNew["Profits"].mean()
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense                            1437.100000
# Apparel              Apparel                                           549.066667
# Business Services    Advertising, marketing                            774.500000
#                      Diversified Outsourcing Services                  307.500000
#                      Education                                          23.000000
#                                                                          ...
# Transportation       Trucking, Truck Leasing                           212.222222
# Wholesalers          Miscellaneous                                      17.000000
#                      Wholesalers: Diversified                          207.720000
#                      Wholesalers: Electronics and Office Equipment     232.125000
#                      Wholesalers: Food and Grocery                     194.333333
# Name: Profits, Length: 79, dtype: float64

# %%
sector_group["Profits"].mean()
# Out:
# Sector
# Aerospace & Defense             1437.100000
# Apparel                          549.066667
# Business Services                553.470588
# Chemicals                        754.266667
# Energy                          -602.024590
# Engineering & Construction       204.000000
# Financials                      1872.007194
# Food and Drug Stores            1117.266667
# Food, Beverages & Tobacco       1195.744186
# Health Care                     1414.853333
# Hotels, Resturants & Leisure     827.880000
# Household Products               515.285714
# Industrials                      451.391304
# Materials                        102.976744
# Media                            973.880000
# Motor Vehicles & Parts          1079.083333
# Retailing                        597.875000
# Technology                      1769.343137
# Telecommunications              3242.466667
# Transportation                  1226.916667
# Wholesalers                      205.825000
# ...

# %%
sectorNew.mean()
# Out:
# C:\Users\Tushar\AppData\Local\Temp\ipykernel_1640\2215321112.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sectorNew.mean()
#                                                                          Rank  \
# Sector              Industry
# Aerospace & Defense Aerospace and Defense                          443.500000
# Apparel             Apparel                                        583.800000
# Business Services   Advertising, marketing                         270.500000
#                     Diversified Outsourcing Services               643.928571
#                     Education                                      850.000000
# ...                                                                       ...
# ...

# %%
sector_group.mean()
# Out:
# C:\Users\Tushar\AppData\Local\Temp\ipykernel_1640\421288903.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sector_group.mean()
#                                     Rank       Revenue      Profits  \
# Sector
# Aerospace & Defense           443.500000  17897.000000  1437.100000
# Apparel                       583.800000   6397.866667   549.066667
# Business Services             609.294118   5337.156863   553.470588
# Chemicals                     530.933333   8129.900000   754.266667
# Energy                        509.827869  12441.057377  -602.024590
# Engineering & Construction    582.576923   5922.423077   204.000000
# Financials                    457.309353  15950.784173  1872.007194
# Food and Drug Stores          428.600000  32251.266667  1117.266667
# ...

# %%
# Revenue	Profits	Employees
sector_group.agg({"Revenue":"sum",
                 "Profits":"mean"})
# Out:
#                               Revenue      Profits
# Sector
# Aerospace & Defense            357940  1437.100000
# Apparel                         95968   549.066667
# Business Services              272195   553.470588
# Chemicals                      243897   754.266667
# Energy                        1517809  -602.024590
# Engineering & Construction     153983   204.000000
# Financials                    2217159  1872.007194
# Food and Drug Stores           483769  1117.266667
# Food, Beverages & Tobacco      555967  1195.744186
# Health Care                   1614707  1414.853333
# Hotels, Resturants & Leisure   169546   827.880000
# Household Products             234737   515.285714
# Industrials                    497581   451.391304
# Materials                      259145   102.976744
# Media                          220764   973.880000
# Motor Vehicles & Parts         482540  1079.083333
# Retailing                     1465076   597.875000
# ...

# %%
# Revenue	Profits	Employees
sectorNew.agg({"Revenue":"sum",
                 "Profits":"mean"})
# Out:
#                                                                    Revenue  \
# Sector              Industry
# Aerospace & Defense Aerospace and Defense                           357940
# Apparel             Apparel                                          95968
# Business Services   Advertising, marketing                           22748
#                     Diversified Outsourcing Services                 64829
#                     Education                                         7485
# ...                                                                    ...
# Transportation      Trucking, Truck Leasing                          35950
# Wholesalers         Miscellaneous                                     8982
#                     Wholesalers: Diversified                        176138
#                     Wholesalers: Electronics and Office Equipment   147906
#                     Wholesalers: Food and Grocery                   111774
#
# ...
