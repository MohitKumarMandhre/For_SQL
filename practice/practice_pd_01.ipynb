# %% [markdown]
# ## pandas

# %%
import pandas as pd

# %%
mydataset = {
    'cars': ['bmw', 'volvo', 'ford'],
    'passings': [3, 7, 2]
}

var = pd.DataFrame( mydataset)
print( var)
# Out:
#     cars  passings
# 0    bmw         3
# 1  volvo         7
# 2   ford         2

# %%
pd.__version__
# Out:
# '1.3.5'

# %%
a = [2, 4, 8]
ser = pd.Series( a, index=["x", "y", "z"])
print( ser, ser[0], ser["z"])
# Out:
# x    2
# y    4
# z    8
# dtype: int64 2 8

# %%
cal = {
    "d1":420, "d2":380, "d3":390
}
mcal = pd.Series( cal)
# print( mv)

# %%
data = {
    "cal" : [420, 360, 390],
    "duration": [50, 40, 45]
}

mv = pd.DataFrame( data)
# print( mv)
print( mv.loc[[2, 1, 0]] )
# Out:
#    cal  duration
# 2  390        45
# 1  360        40
# 0  420        50

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix

from joblib import dump, load

# %%
df = pd.read_csv( 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data')
df.describe()
# Out:
#               5.1         3.5         1.4         0.2
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
# print( df.to_string() )
# print( pd.options.display.max_rows )
df
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df2 = pd.DataFrame( df)
# print( df)
print( type( df2), type( df))
# Out:
# <class 'pandas.core.frame.DataFrame'> <class 'pandas.core.frame.DataFrame'>

# %%
df2.tail( 10)
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 139  6.7  3.1  5.6  2.4  Iris-virginica
# 140  6.9  3.1  5.1  2.3  Iris-virginica
# 141  5.8  2.7  5.1  1.9  Iris-virginica
# 142  6.8  3.2  5.9  2.3  Iris-virginica
# 143  6.7  3.3  5.7  2.5  Iris-virginica
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   5.1          149 non-null    float64
#  1   3.5          149 non-null    float64
#  2   1.4          149 non-null    float64
#  3   0.2          149 non-null    float64
#  4   Iris-setosa  149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
df.dropna() 
df.head( 20)
# Out:
#     5.1  3.5  1.4  0.2  Iris-setosa
# 0   4.9  3.0  1.4  0.2  Iris-setosa
# 1   4.7  3.2  1.3  0.2  Iris-setosa
# 2   4.6  3.1  1.5  0.2  Iris-setosa
# 3   5.0  3.6  1.4  0.2  Iris-setosa
# 4   5.4  3.9  1.7  0.4  Iris-setosa
# 5   4.6  3.4  1.4  0.3  Iris-setosa
# 6   5.0  3.4  1.5  0.2  Iris-setosa
# 7   4.4  2.9  1.4  0.2  Iris-setosa
# 8   4.9  3.1  1.5  0.1  Iris-setosa
# 9   5.4  3.7  1.5  0.2  Iris-setosa
# 10  4.8  3.4  1.6  0.2  Iris-setosa
# 11  4.8  3.0  1.4  0.1  Iris-setosa
# 12  4.3  3.0  1.1  0.1  Iris-setosa
# 13  5.8  4.0  1.2  0.2  Iris-setosa
# 14  5.7  4.4  1.5  0.4  Iris-setosa
# 15  5.4  3.9  1.3  0.4  Iris-setosa
# 16  5.1  3.5  1.4  0.3  Iris-setosa
# 17  5.7  3.8  1.7  0.3  Iris-setosa
# 18  5.1  3.8  1.5  0.3  Iris-setosa
# 19  5.4  3.4  1.7  0.2  Iris-setosa

# %%
data = {
    "cal" : [np.nan, 360, 390, 250, np.nan, 390, 390, 360, np.nan, 360],
    "duration": [50, 40, 45, np.nan, np.nan, 45, 45, 40, np.nan, 40],
    "date": ['2022/01/01', '2022/01/02', '2022/01/03', np.nan, '2022/01/04', '2022/01/05', '2022/01/06', '2022/01/07', np.nan, '2022/01/07' ]
}

mv = pd.DataFrame( data)
# print( mv)
print( mv )
# Out:
#      cal  duration        date
# 0    NaN      50.0  2022/01/01
# 1  360.0      40.0  2022/01/02
# 2  390.0      45.0  2022/01/03
# 3  250.0       NaN         NaN
# 4    NaN       NaN  2022/01/04
# 5  390.0      45.0  2022/01/05
# 6  390.0      45.0  2022/01/06
# 7  360.0      40.0  2022/01/07
# 8    NaN       NaN         NaN
# 9  360.0      40.0  2022/01/07

# %%
ndf = mv.dropna( )
print( ndf)
# Out:
#      cal  duration        date
# 1  360.0      40.0  2022/01/02
# 2  390.0      45.0  2022/01/03
# 5  390.0      45.0  2022/01/05
# 6  390.0      45.0  2022/01/06
# 7  360.0      40.0  2022/01/07

# %%
fdf = mv.fillna( 0)
print( fdf)
# Out:
#      cal  duration        date
# 0    0.0      50.0  2022/01/01
# 1  360.0      40.0  2022/01/02
# 2  390.0      45.0  2022/01/03
# 3  250.0       0.0           0
# 4    0.0       0.0  2022/01/04
# 5  390.0      45.0  2022/01/05
# 6  390.0      45.0  2022/01/06
# 7  360.0      40.0  2022/01/07
# 8    0.0       0.0           0

# %%
x = mv['cal'].median()
rdf = mv['cal'].fillna( x)
print( rdf)
# Out:
# 0    375.0
# 1    360.0
# 2    390.0
# 3    250.0
# 4    375.0
# 5    390.0
# 6    390.0
# 7    360.0
# 8    375.0
# Name: cal, dtype: float64

# %%
y = mv["cal"].mode()[0]
print( y)
# Out:
# 390.0

# %%
adf=mv
adf['date'] = pd.to_datetime( mv['date'])
print( adf)
# Out:
#      cal  duration       date
# 0    NaN      50.0 2022-01-01
# 1  360.0      40.0 2022-01-02
# 2  390.0      45.0 2022-01-03
# 3  250.0       NaN        NaT
# 4    NaN       NaN 2022-01-04
# 5  390.0      45.0 2022-01-05
# 6  390.0      45.0 2022-01-06
# 7  360.0      40.0 2022-01-07
# 8    NaN       NaN        NaT

# %%
bdf = mv
print( bdf.loc[[0, 1]])
# Out:
#      cal  duration       date
# 0    NaN      50.0 2022-01-01
# 1  360.0      40.0 2022-01-02

# %%
mv
# Out:
#      cal  duration       date
# 0    NaN      50.0 2022-01-01
# 1  360.0      40.0 2022-01-02
# 2  390.0      45.0 2022-01-03
# 3  250.0       NaN        NaT
# 4    NaN       NaN 2022-01-04
# 5  390.0      45.0 2022-01-05
# 6  390.0      45.0 2022-01-06
# 7  360.0      40.0 2022-01-07
# 8    NaN       NaN        NaT

# %%
cdf = mv
cdf.loc[2, 'duration'] = 77
cdf
# Out:
#      cal  duration        date
# 0    NaN      50.0  2022/01/01
# 1  360.0      40.0  2022/01/02
# 2  390.0      77.0  2022/01/03
# 3  250.0       NaN         NaN
# 4    NaN       NaN  2022/01/04
# 5  390.0      45.0  2022/01/05
# 6  390.0      45.0  2022/01/06
# 7  360.0      40.0  2022/01/07
# 8    NaN       NaN         NaN
# 9  360.0      40.0  2022/01/07

# %%
cdf.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
for x in cdf.index:
  # print( x)
  if cdf.loc[x, 'duration'] > 50:
    print( x, cdf.loc[x, 'duration'], "gt50")
  else:
    print( x, cdf.loc[x, 'duration'], "lt50")
# Out:
# 0 50.0 lt50
# 1 40.0 lt50
# 2 77.0 gt50
# 3 nan lt50
# 4 nan lt50
# 5 45.0 lt50
# 6 45.0 lt50
# 7 40.0 lt50
# 8 nan lt50

# %%
cdf.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9     True
# dtype: bool

# %%
df.corr()
# Out:
#           5.1       3.5       1.4       0.2
# 5.1  1.000000 -0.103784  0.871283  0.816971
# 3.5 -0.103784  1.000000 -0.415218 -0.350733
# 1.4  0.871283 -0.415218  1.000000  0.962314
# 0.2  0.816971 -0.350733  0.962314  1.000000

# %%
cdf.plot()

# %%
df.plot()

# %% [markdown]
# ###########################################

# %%
cols = ['sepal_length', ' sepal_width', 'petal_length', 'petal_width', 'class']
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', names=cols)
df.head()
# Out:
#    sepal_length   sepal_width  petal_length  petal_width        class
# 0           5.1           3.5           1.4          0.2  Iris-setosa
# 1           4.9           3.0           1.4          0.2  Iris-setosa
# 2           4.7           3.2           1.3          0.2  Iris-setosa
# 3           4.6           3.1           1.5          0.2  Iris-setosa
# 4           5.0           3.6           1.4          0.2  Iris-setosa

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
cols = ['sepal_length', ' sepal_width', 'petal_length', 'petal_width', 'class']
iris = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', names=cols)
iris.head()
# Out:
#    sepal_length   sepal_width  petal_length  petal_width        class
# 0           5.1           3.5           1.4          0.2  Iris-setosa
# 1           4.9           3.0           1.4          0.2  Iris-setosa
# 2           4.7           3.2           1.3          0.2  Iris-setosa
# 3           4.6           3.1           1.5          0.2  Iris-setosa
# 4           5.0           3.6           1.4          0.2  Iris-setosa

# %%
## mean & median of different species present in data set
iris.groupby( 'class').agg(['mean', 'median'])
# Out:
#                 sepal_length         sepal_width        petal_length         \
#                         mean median         mean median         mean median
# class
# Iris-setosa            5.006    5.0        3.418    3.4        1.464   1.50
# Iris-versicolor        5.936    5.9        2.770    2.8        4.260   4.35
# Iris-virginica         6.588    6.5        2.974    3.0        5.552   5.55
#
#                 petal_width
#                        mean median
# class
# Iris-setosa           0.244    0.2
# Iris-versicolor       1.326    1.3
# Iris-virginica        2.026    2.0

# %%
## shows symmetrically distributed data with very less presence of outliers

iris.groupby( 'class').std()
# Out:
#                  sepal_length   sepal_width  petal_length  petal_width
# class
# Iris-setosa          0.352490      0.381024      0.173511     0.107210
# Iris-versicolor      0.516171      0.313798      0.469911     0.197753
# Iris-virginica       0.635880      0.322497      0.551895     0.274650

# %% [markdown]
# #################################

# %%
iris.describe()
# Out:
#        sepal_length   sepal_width  petal_length  petal_width
# count    150.000000    150.000000    150.000000   150.000000
# mean       5.843333      3.054000      3.758667     1.198667
# std        0.828066      0.433594      1.764420     0.763161
# min        4.300000      2.000000      1.000000     0.100000
# 25%        5.100000      2.800000      1.600000     0.300000
# 50%        5.800000      3.000000      4.350000     1.300000
# 75%        6.400000      3.300000      5.100000     1.800000
# max        7.900000      4.400000      6.900000     2.500000

# %%
## chk for duplicate values
iris[ iris.duplicated() ]
# Out:
#      sepal_length   sepal_width  petal_length  petal_width           class
# 34            4.9           3.1           1.5          0.1     Iris-setosa
# 37            4.9           3.1           1.5          0.1     Iris-setosa
# 142           5.8           2.7           5.1          1.9  Iris-virginica

# %%
iris['class'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: class, dtype: int64

# %%
plt.title('Class Count')
sns.countplot( iris['class'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,11))
sns.heatmap(iris.corr(),annot=True)
plt.plot()
# Out:
# []
